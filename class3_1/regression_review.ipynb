# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.preprocessing import Imputer
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %% [markdown]
# ## Setting things up

# %% [markdown]
# Let's load the data and give it a quick look.

# %%
df = pd.read_csv('data/apib12tx.csv')

# %%
df.describe()
# Out:
#              API12B        PCT_AA        PCT_AI        PCT_AS        PCT_FI  \
# count  10187.000000  10187.000000  10187.000000  10187.000000  10187.000000
# mean     787.467262      6.504172      1.109257      7.154216      2.149602
# std      104.176630     10.539728      4.082059     12.321782      4.028955
# min      317.000000      0.000000      0.000000      0.000000      0.000000
# 25%      739.000000      1.000000      0.000000      1.000000      0.000000
# 50%      797.000000      3.000000      0.000000      3.000000      1.000000
# 75%      857.000000      8.000000      1.000000      8.000000      3.000000
# max      998.000000     95.000000     92.000000     96.000000     65.000000
#
#              PCT_HI        PCT_PI        PCT_WH        PCT_MR         MEALS  \
# count  10187.000000  10187.000000  10187.000000  10187.000000  10187.000000
# mean      49.908216      0.504957     29.520467      2.085108     59.667517
# std       29.159250      1.031627     26.159148      2.939391     29.600844
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       24.000000      0.000000      5.000000      0.000000     36.000000
# 50%       48.000000      0.000000     22.000000      1.000000     64.000000
# 75%       76.000000      1.000000     51.000000      3.000000     85.000000
# max      100.000000     18.000000    100.000000     23.000000    100.000000
#
#            ...            ACS_K3       ACS_46     ACS_CORE      PCT_RESP  \
# count      ...       6634.000000  7511.000000  4489.000000  10187.000000
# mean       ...         22.059090    25.723605    23.432168     85.550702
# std        ...          5.839773     6.902056     7.683286     18.622835
# min        ...          1.000000     1.000000     1.000000      0.000000
# 25%        ...         20.000000    24.000000    20.000000     82.000000
# 50%        ...         23.000000    28.000000    26.000000     92.000000
# 75%        ...         26.000000    30.000000    29.000000     97.000000
# max        ...         43.000000    46.000000    45.000000    100.000000
#
#             NOT_HSG           HSG      SOME_COL      COL_GRAD      GRAD_SCH  \
# count  10187.000000  10187.000000  10187.000000  10187.000000  10187.000000
# mean      20.058506     24.698537     24.264651     18.515952     11.794935
# std       17.679325     12.319831     11.020448     12.452289     13.874110
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        5.000000     16.000000     16.000000      8.000000      3.000000
# 50%       16.000000     26.000000     24.000000     16.000000      6.000000
# 75%       32.000000     33.000000     32.000000     28.000000     16.000000
# max      100.000000    100.000000    100.000000    100.000000     89.000000
#
#              AVG_ED
# count  10118.000000
# mean       2.771169
# std        0.754851
# min        1.000000
# 25%        2.180000
# 50%        2.670000
# 75%        3.290000
# max        4.880000
#
# [8 rows x 25 columns]

# %% [markdown]
# ## Checking out correlations

# %% [markdown]
# Let's start looking at how variables in our dataset relate to each other so we know what to expect when we start modeling.

# %%
df.corr()
# Out:
#             API12B    PCT_AA    PCT_AI    PCT_AS    PCT_FI    PCT_HI  \
# API12B    1.000000 -0.223117 -0.126489  0.362361  0.153552 -0.418466
# PCT_AA   -0.223117  1.000000 -0.067107 -0.049370  0.057254 -0.092423
# P_MIGED  -0.093803 -0.214935 -0.177547  0.263676    ...     0.036802
# P_EL      0.024503 -0.665903 -0.341988  0.636838    ...     0.138346
# P_RFEP   -0.007727 -0.557736 -0.303721  0.397674    ...     0.108101
# P_DI      0.029540  0.023305  0.006032  0.049876    ...    -0.301005
# ACS_K3    0.075881 -0.176037  0.007579  0.017383    ...     1.000000
# ACS_46    0.049283 -0.131902  0.056607 -0.035894    ...     0.793651
# ACS_CORE  0.019570 -0.126703 -0.053738 -0.095275    ...     0.699465
# PCT_RESP -0.029653  0.175599  0.132515 -0.164411    ...     0.138815
# NOT_HSG  -0.052520 -0.664536 -0.408829  0.734150    ...     0.024870
# HSG       0.083561 -0.494585 -0.295447  0.710693    ...    -0.014883
# SOME_COL  0.092990  0.286760  0.113340 -0.079904    ...    -0.033463
# COL_GRAD  0.009552  0.580454  0.378918 -0.785937    ...     0.005454
# GRAD_SCH -0.081522  0.522910  0.348351 -0.754539    ...     0.005000
# AVG_ED   -0.017244  0.683077  0.432389 -0.872949    ...    -0.005821
#
#             ACS_46  ACS_CORE  PCT_RESP   NOT_HSG       HSG  SOME_COL  \
# API12B    0.254228  0.437987  0.223457 -0.535325 -0.519386  0.011033
# PCT_AA   -0.070089 -0.036594 -0.178875  0.003424  0.149530  0.134386
# PCT_AI   -0.184140 -0.218363 -0.031626 -0.061002  0.113335  0.145105
# PCT_AS    0.178142  0.251559 -0.004432 -0.271720 -0.252820 -0.213072
# PCT_FI    0.120321  0.214681  0.068215 -0.204777 -0.083519  0.090039
# PCT_HI    0.069356  0.048252 -0.084089  0.798176  0.520316 -0.268786
# PCT_PI    0.049283  0.019570 -0.029653 -0.052520  0.083561  0.092990
# PCT_WH   -0.131902 -0.126703  0.175599 -0.664536 -0.494585  0.286760
# PCT_MR    0.056607 -0.053738  0.132515 -0.408829 -0.295447  0.113340
# MEALS    -0.035894 -0.095275 -0.164411  0.734150  0.710693 -0.079904
# P_GATE    0.143832  0.371522  0.001516 -0.181664 -0.192168 -0.047112
# P_MIGED  -0.013519 -0.028966  0.056428  0.376072  0.124583 -0.157987
# P_EL      0.109007  0.004258 -0.095159  0.707431  0.413443 -0.398401
# P_RFEP    0.111874  0.256516 -0.124148  0.532067  0.245830 -0.336218
# P_DI     -0.287175 -0.207121 -0.165832 -0.020500  0.063822  0.024405
# ACS_K3    0.793651  0.699465  0.138815  0.024870 -0.014883 -0.033463
# ACS_46    1.000000  0.797873  0.159163 -0.031117 -0.045236 -0.051904
# ACS_CORE  0.797873  1.000000  0.123847 -0.083922 -0.166419 -0.071366
# PCT_RESP  0.159163  0.123847  1.000000 -0.119829 -0.130072  0.173556
# NOT_HSG  -0.031117 -0.083922 -0.119829  1.000000  0.430125 -0.441862
# HSG      -0.045236 -0.166419 -0.130072  0.430125  1.000000  0.012790
# SOME_COL -0.051904 -0.071366  0.173556 -0.441862  0.012790  1.000000
# COL_GRAD  0.073514  0.202447  0.170700 -0.746153 -0.691139  0.092047
# GRAD_SCH  0.058967  0.164005  0.200911 -0.580582 -0.727006 -0.216354
# AVG_ED    0.056500  0.160656  0.204639 -0.879174 -0.754308  0.147892
#
#           COL_GRAD  GRAD_SCH    AVG_ED
# API12B    0.591692  0.582731  0.652429
# PCT_AA   -0.097386 -0.151995 -0.098450
# PCT_AI   -0.075846 -0.075958 -0.030800
# PCT_AS    0.326789  0.389559  0.370071
# PCT_FI    0.263867  0.031945  0.165709
# PCT_HI   -0.685352 -0.602600 -0.797608
# PCT_PI    0.009552 -0.081522 -0.017244
# PCT_WH    0.580454  0.522910  0.683077
# PCT_MR    0.378918  0.348351  0.432389
# MEALS    -0.785937 -0.754539 -0.872949
# P_GATE    0.224105  0.234954  0.241601
# P_MIGED  -0.273858 -0.201256 -0.316049
# P_EL     -0.536341 -0.447442 -0.654460
# P_RFEP   -0.356630 -0.292245 -0.457698
# P_DI     -0.026593 -0.062990 -0.031134
# ACS_K3    0.005454  0.005000 -0.005821
# ACS_46    0.073514  0.058967  0.056500
# ACS_CORE  0.202447  0.164005  0.160656
# PCT_RESP  0.170700  0.200911  0.204639
# NOT_HSG  -0.746153 -0.580582 -0.879174
# HSG      -0.691139 -0.727006 -0.754308
# SOME_COL  0.092047 -0.216354  0.147892
# COL_GRAD  1.000000  0.667201  0.884819
# GRAD_SCH  0.667201  1.000000  0.874638
# AVG_ED    0.884819  0.874638  1.000000
#
# [25 rows x 25 columns]

# %% [markdown]
# The percentage of students enrolled in free/reduced-price lunch programs is often used as a proxy for poverty.

# %%
df.plot(kind="scatter", x="MEALS", y="API12B")

# %% [markdown]
# Conversely, the education level of a student's parents is often a good predictor of how well a student will do in school.

# %%
df.plot(kind="scatter", x="AVG_ED", y="API12B")

# %% [markdown]
# ## Running the regression

# %% [markdown]
# Like we did last week, we'll use scikit-learn to run basic single-variable regressions.

# %%
data = np.asarray(df[['API12B','MEALS']])
data = Imputer().fit_transform(data)
x, y = data[:, 1:], data[:, 0]

# %%
lr = LinearRegression() 
lr.fit(x, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# plot the linear regression line on the scatter plot
lr.coef_
# Out:
# array([-1.85881873])

# %%
lr.score(x, y)
# Out:
# 0.42931186318861703

# %%
plt.scatter(x, y, color='blue')
plt.plot(x, lr.predict(x), color='red', linewidth=1)

# %% [markdown]
# ## Multiple regression

# %% [markdown]
# Lorem ipsum

# %%
lr = LinearRegression()
data = np.asarray(df[['API12B','MEALS','AVG_ED','ACS_CORE', 'PCT_AA', 'PCT_WH']].fillna(0))
x, y = data[:, 1:], data[:, 0]

# %%
lr.fit(x,y) #fit the data to the values
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lr.coef_
# Out:
# array([ -0.53663312,  76.41324647,  -1.02291313,  -1.8678355 ,  -0.66624921])
